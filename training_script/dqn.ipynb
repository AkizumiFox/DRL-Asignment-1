# %%
# !pip install --upgrade gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 7.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym) (0.0.8)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827697 sha256=11697e7d01c6bd0b29afdf3115faafaee7c69d8324c2edd66fc343a0b090dd00
#   Stored in directory: /root/.cache/pip/wheels/1c/77/9e/9af5470201a0b0543937933ee99ba884cd237d2faefe8f4d37
# Successfully built gym
# Installing collected packages: gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# Successfully installed gym-0.26.2

# %%
import random

class Maze:
    def __init__(self, n):
        """
        Initialize the maze of size (n+2) x (n+2). This includes a border of walls
        around an n x n interior. If n is even, also carves row n and column n
        so they're not fully blocked.
        """
        self.n = n
        self.size = n + 2
        self.maze = [['#' for _ in range(self.size)] for _ in range(self.size)]

        # Two sets for storing coordinates of walls and blanks
        self.wall_coords = set()
        self.blank_coords = set()

        # List to store the station coordinates
        self.stations = []

        # Lists to store taxi and passenger information
        self.taxi_location = []
        self.pass_idx = None  # Station index (0-3) for passenger location
        self.dest_idx = None  # Station index (0-3) for destination
        self.passenger_loc = None  # Actual coordinates of passenger location
        self.destination = None  # Actual coordinates of destination
        self.passenger_picked_up = False  # Track if passenger is in taxi
        self.fuel = 5000  # Initialize fuel

        # Generate the maze on initialization
        self._generate_maze()

        # Fill in the wall_coords and blank_coords sets based on the final maze
        self._populate_coordinate_sets()

        # Select the stations
        self._select_stations()

        # Select taxi location and passenger information
        self._select_taxi_and_passenger()

    def _generate_maze(self):
        """
        Internal method to carve out the maze using a DFS approach.
        """
        # 1) Mark interior carveable cells
        for row in range(1, self.n + 1):
            for col in range(1, self.n + 1):
                # Standard "odd cell" carve
                if row % 2 == 1 and col % 2 == 1:
                    self.maze[row][col] = ' '
                # If n is even, also open up the entire row n and col n
                elif self.n % 2 == 0:
                    if row == self.n or col == self.n:
                        self.maze[row][col] = ' '

        # 2) Perform DFS from the top-left carveable cell (1, 1)
        visited = set()

        def dfs(r, c):
            visited.add((r, c))
            for (nr, nc) in self._neighbors(r, c):
                if (nr, nc) not in visited:
                    # Carve a path between (r, c) and (nr, nc)
                    wall_r = (r + nr) // 2
                    wall_c = (c + nc) // 2
                    self.maze[wall_r][wall_c] = ' '
                    dfs(nr, nc)

        # Run DFS
        dfs(1, 1)

    def _neighbors(self, r, c):
        """
        Yield neighbor cells that are 2 steps away in the four
        cardinal directions, randomly shuffled.
        """
        directions = [(-2, 0), (2, 0), (0, -2), (0, 2)]
        random.shuffle(directions)
        for dr, dc in directions:
            nr, nc = r + dr, c + dc
            # Ensure the neighbor is valid and currently carved (i.e., ' ').
            if 1 <= nr <= self.n and 1 <= nc <= self.n and self.maze[nr][nc] == ' ':
                yield nr, nc

    def _populate_coordinate_sets(self):
        """
        Populate wall_coords and blank_coords based on the final
        layout in self.maze.
        """
        for r in range(self.size):
            for c in range(self.size):
                if self.maze[r][c] == '#':
                    self.wall_coords.add((r, c))
                else:
                    self.blank_coords.add((r, c))

    def _select_stations(self):
        """
        Randomly selects 4 blank cells to serve as stations.
        Stores their coordinates in self.stations as a list of [row, col] lists.
        """
        # Convert blank_coords to a list for random sampling
        blank_list = list(self.blank_coords)

        # Randomly select 4 coordinates (or fewer if there aren't enough blanks)
        num_stations = min(4, len(blank_list))
        selected_coords = random.sample(blank_list, num_stations)

        # Convert each tuple to a list and store in self.stations
        self.stations = [list(coord) for coord in selected_coords]

    def _select_taxi_and_passenger(self):
        """
        Randomly selects a blank cell for the taxi (not a station).
        Randomly selects two different stations for passenger location and destination.
        """
        # Get blank cells that are not stations
        station_coords = {tuple(station) for station in self.stations}
        available_coords = list(self.blank_coords - station_coords)

        # Select taxi location from available blank cells
        if available_coords:
            taxi_coord = random.choice(available_coords)
            self.taxi_location = list(taxi_coord)
        else:
            self.taxi_location = []

        # Select passenger location and destination from different stations
        if len(self.stations) >= 2:
            # Randomly select two different station indices
            station_indices = list(range(len(self.stations)))
            selected_indices = random.sample(station_indices, 2)

            self.pass_idx = selected_indices[0]
            self.dest_idx = selected_indices[1]

            # Store the actual coordinates
            self.passenger_loc = self.stations[self.pass_idx]
            self.destination = self.stations[self.dest_idx]
        else:
            # Fallback if there are fewer than 2 stations
            self.pass_idx = None
            self.dest_idx = None
            self.passenger_loc = None
            self.destination = None

    def step(self, action):
        """
        Execute an action and update the environment state.

        Args:
            action (int):
                0: Move south
                1: Move north
                2: Move east
                3: Move west
                4: Pick up passenger
                5: Drop off passenger

        Returns:
            tuple: (observation, reward, done, False, False)
                - observation: Current state
                - reward: Reward for the action
                - done: Whether the episode is terminated
                - False: Placeholder
                - False: Placeholder
        """
        # Initialize reward (each step costs -0.1)
        reward = -0.1

        # Reduce fuel by 1
        self.fuel -= 1

        # Check if fuel is empty
        if self.fuel <= 0:
            return self.get_state(), reward - 10, True, False, False  # Apply fuel exhaustion penalty

        # Movement actions
        if 0 <= action <= 3:
            # Movement directions as (dr, dc) for [south, north, east, west]
            directions = [(0, 1), (0, -1), (1, 0), (-1, 0)]
            dr, dc = directions[action]

            # Calculate new position
            new_r, new_c = self.taxi_location[0] + dr, self.taxi_location[1] + dc

            # Check if the new position is a wall
            if (new_r, new_c) in self.wall_coords:
                reward -= 5  # Penalty for hitting a wall
                return self.get_state(), reward, False, False, False

            # Update taxi location
            self.taxi_location = [new_r, new_c]

        # Pick up passenger
        elif action == 4:
            # Check if taxi is at passenger location and passenger isn't already picked up
            if not self.passenger_picked_up and self.taxi_location == self.passenger_loc:
                self.passenger_picked_up = True
            else:
                reward -= 10  # Penalty for incorrect pickup

        # Drop off passenger
        elif action == 5:
            # Check if taxi is at destination and passenger is in the taxi
            if self.passenger_picked_up and self.taxi_location == self.destination:
                self.passenger_picked_up = False
                reward += 50  # Reward for successful delivery

                # Randomize new passenger and destination
                self._randomize_passenger_and_destination()
            else:
                reward -= 10  # Penalty for incorrect dropoff

        # Return the observation, reward, done flag, and two placeholders
        return self.get_state(), reward, False, False, False

    def _randomize_passenger_and_destination(self):
        """
        Randomly selects new passenger and destination stations.
        The passenger and destination will be at different stations.
        """
        if len(self.stations) >= 2:
            # Randomly select two different station indices
            station_indices = list(range(len(self.stations)))
            selected_indices = random.sample(station_indices, 2)

            self.pass_idx = selected_indices[0]
            self.dest_idx = selected_indices[1]

            # Store the actual coordinates
            self.passenger_loc = self.stations[self.pass_idx]
            self.destination = self.stations[self.dest_idx]

            # Reset passenger status
            self.passenger_picked_up = False

    def __str__(self):
        """
        Allows printing the maze object directly with `print(maze)`.
        """
        return "\n".join("".join(row) for row in self.maze)

    def get_state(self):
        """
        Returns the current state representation as a tuple containing:
        - Taxi position
        - Station coordinates
        - Information about obstacles in cardinal directions
        - Information about passenger and destination visibility

        Returns:
            tuple: State representation
        """
        taxi_row, taxi_col = self.taxi_location

        # Check for obstacles in each direction
        obstacle_north = int((taxi_row - 1, taxi_col) in self.wall_coords)
        obstacle_south = int((taxi_row + 1, taxi_col) in self.wall_coords)
        obstacle_east = int((taxi_row, taxi_col + 1) in self.wall_coords)
        obstacle_west = int((taxi_row, taxi_col - 1) in self.wall_coords)

        # Pad stations list to ensure we have 4 stations
        padded_stations = self.stations + [[0, 0]] * (4 - len(self.stations))

        # Check for passenger visibility in each direction
        passenger_loc = self.passenger_loc
        passenger_loc_north = int(passenger_loc == [taxi_row - 1, taxi_col])
        passenger_loc_south = int(passenger_loc == [taxi_row + 1, taxi_col])
        passenger_loc_east = int(passenger_loc == [taxi_row, taxi_col + 1])
        passenger_loc_west = int(passenger_loc == [taxi_row, taxi_col - 1])
        passenger_loc_middle = int(passenger_loc == [taxi_row, taxi_col])
        passenger_look = passenger_loc_north or passenger_loc_south or passenger_loc_east or passenger_loc_west or passenger_loc_middle

        # Check for destination visibility in each direction
        destination = self.destination
        destination_loc_north = int(destination == [taxi_row - 1, taxi_col])
        destination_loc_south = int(destination == [taxi_row + 1, taxi_col])
        destination_loc_east = int(destination == [taxi_row, taxi_col + 1])
        destination_loc_west = int(destination == [taxi_row, taxi_col - 1])
        destination_loc_middle = int(destination == [taxi_row, taxi_col])
        destination_look = destination_loc_north or destination_loc_south or destination_loc_east or destination_loc_west or destination_loc_middle

        # Construct the state tuple
        state = (
            taxi_row - 1,
            taxi_col - 1,
            padded_stations[0][0] - 1, padded_stations[0][1] - 1,
            padded_stations[1][0] - 1, padded_stations[1][1] - 1,
            padded_stations[2][0] - 1, padded_stations[2][1] - 1,
            padded_stations[3][0] - 1, padded_stations[3][1] - 1,
            obstacle_north, obstacle_south, obstacle_east, obstacle_west,
            passenger_look, destination_look
        )

        return state

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42) if torch.cuda.is_available() else None

# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Neural Network for DQN
class DQNetwork(nn.Module):
    def __init__(self, state_size, action_size, hidden_size=64):
        super(DQNetwork, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Experience Replay Buffer
class ReplayBuffer:
    def __init__(self, buffer_size):
        self.buffer = deque(maxlen=buffer_size)

    def add(self, obs, action, reward, next_obs, done):
        self.buffer.append((obs, action, reward, next_obs, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        observations, actions, rewards, next_observations, dones = zip(*batch)

        # Convert to numpy arrays first for better performance
        observations = np.array(observations, dtype=np.float32)
        actions = np.array(actions, dtype=np.int64)
        rewards = np.array(rewards, dtype=np.float32)
        next_observations = np.array(next_observations, dtype=np.float32)
        dones = np.array(dones, dtype=np.float32)

        return (
            torch.tensor(observations).to(device),
            torch.tensor(actions).to(device),
            torch.tensor(rewards).to(device),
            torch.tensor(next_observations).to(device),
            torch.tensor(dones).to(device)
        )

    def __len__(self):
        return len(self.buffer)

# DQN Agent updated for once-per-episode learning and epsilon decay per episode
class DQNAgent:
    def __init__(self, state_size, action_size, buffer_size=10000, batch_size=64,
                 gamma=0.99, learning_rate=0.001, tau=0.001):
        self.state_size = state_size
        self.action_size = action_size
        self.batch_size = batch_size
        self.gamma = gamma  # discount factor
        self.tau = tau      # for soft update of target network

        # Q-Networks (policy and target)
        self.policy_net = DQNetwork(state_size, action_size).to(device)
        self.target_net = DQNetwork(state_size, action_size).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()  # Target network is not trained directly

        # Optimizer
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=learning_rate)

        # Replay buffer
        self.memory = ReplayBuffer(buffer_size)

        # Exploration parameters
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.9999  # Decay applied once per episode

    def act(self, obs, eval_mode=False):
        """Select an action using epsilon-greedy policy"""
        if (not eval_mode) and random.random() < self.epsilon:
            return random.randrange(self.action_size)

        obs = torch.FloatTensor(obs).unsqueeze(0).to(device)
        self.policy_net.eval()
        with torch.no_grad():
            action_values = self.policy_net(obs)
        self.policy_net.train()

        return torch.argmax(action_values, dim=1).item()

    def step(self, obs, action, reward, next_obs, done):
        """Add experience to memory.
           Epsilon decay is now handled once per episode in the training loop."""
        self.memory.add(obs, action, reward, next_obs, done)

    def learn(self):
        """Perform a single learning step using a batch of experience tuples"""
        # Sample from memory
        observations, actions, rewards, next_observations, dones = self.memory.sample(self.batch_size)

        # Get Q values for current states
        Q_expected = self.policy_net(observations).gather(1, actions.unsqueeze(1)).squeeze(1)

        # Get max Q values for next states from target model
        with torch.no_grad():
            Q_targets_next = self.target_net(next_observations).max(1)[0]

        # Compute target Q values
        Q_targets = rewards + (self.gamma * Q_targets_next * (1 - dones))

        # Calculate loss
        loss = nn.MSELoss()(Q_expected, Q_targets)

        # Minimize loss
        self.optimizer.zero_grad()
        loss.backward()
        # Gradient clipping to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1)
        self.optimizer.step()

        # Soft update target network
        self.soft_update()

    def soft_update(self):
        """Soft update of target network parameters"""
        for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
            target_param.data.copy_(self.tau * policy_param.data + (1.0 - self.tau) * target_param.data)

    def save(self, filename):
        """Save the model"""
        torch.save({
            'policy_model_state_dict': self.policy_net.state_dict(),
            'target_model_state_dict': self.target_net.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'epsilon': self.epsilon
        }, filename)

    def load(self, filename):
        """Load the model"""
        checkpoint = torch.load(filename)
        self.policy_net.load_state_dict(checkpoint['policy_model_state_dict'])
        self.target_net.load_state_dict(checkpoint['target_model_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.epsilon = checkpoint['epsilon']

# Function to preprocess the state for the neural network
def preprocess_state(state):
    """Convert tuple state to numpy array for neural network input"""
    return np.array(state, dtype=np.float32)

# Training function updated to perform learning once per episode and decay epsilon once per episode
def train_dqn(env, agent, num_episodes=100000, max_steps=1000, print_every=100):
    """Train DQN agent with one update per episode and epsilon decay applied once per episode"""
    scores = []
    recent_scores = deque(maxlen=100)  # Last 100 scores for monitoring improvement

    for episode in tqdm(range(1, num_episodes+1)):
        # Reset environment at start of episode
        env = Maze(random.randint(5, 10))
        obs = preprocess_state(env.get_state())
        score = 0

        for t in range(max_steps):
            # Select an action
            action = agent.act(obs)

            # Take action and observe next state and reward
            next_obs, reward, done, _, _ = env.step(action)
            next_obs = preprocess_state(next_obs)

            # Store experience (learning is not done here)
            agent.step(obs, action, reward, next_obs, done)

            # Update state and score
            obs = next_obs
            score += reward

            if done:
                break

        # Perform a single parameter update at the end of the episode if possible
        if len(agent.memory) >= agent.batch_size:
            agent.learn()

        # Decay epsilon once per episode
        agent.epsilon = max(agent.epsilon_min, agent.epsilon * agent.epsilon_decay)

        scores.append(score)
        recent_scores.append(score)

        if episode % print_every == 0:
            print(f"Episode {episode}/{num_episodes} | Average Score: {np.mean(recent_scores):.2f} | Epsilon: {agent.epsilon:.4f}")
            # Save a checkpoint
            agent.save(f"dqn_checkpoint_ep{episode}.pt")

    # Save final model after training
    agent.save("dqn_final.pt")

    return scores

# Evaluation function
def evaluate(env, agent, num_episodes=10, render=False):
    """Evaluate a trained agent"""
    total_rewards = []

    for episode in range(num_episodes):
        # Reset environment
        env = Maze(random.randint(5, 10))
        obs = preprocess_state(env.get_state())
        total_reward = 0
        done = False
        step = 0

        while not done and step < 1000:
            # Select an action (no exploration)
            action = agent.act(obs, eval_mode=True)

            # Take action
            next_obs, reward, done, _, _ = env.step(action)
            next_obs = preprocess_state(next_obs)

            # Update state and reward
            obs = next_obs
            total_reward += reward
            step += 1

            # Render if requested
            if render:
                clear_screen()  # Assuming you have a function to clear the screen
                display_state(env)  # And a function to display the maze
                print(f"Action: {action}")
                print(f"Reward: {reward:.1f}")
                print(f"Total Reward: {total_reward:.1f}")
                input("Press Enter to continue...")

        total_rewards.append(total_reward)
        print(f"Episode {episode+1}: Total Reward = {total_reward:.2f}, Steps = {step}")

    print(f"Average Reward over {num_episodes} episodes: {np.mean(total_rewards):.2f}")
    return total_rewards

# Main function to train and evaluate DQN agent with once-per-episode updates
def main_func():
    # Create environment and agent
    env = Maze(6)  # Initialize with maze size 6 (ensure Maze is defined)
    state_size = len(env.get_state())
    action_size = 6  # Example: South, North, East, West, Pickup, Dropoff

    agent = DQNAgent(state_size, action_size)

    print("Training agent...")
    scores = train_dqn(env, agent)

    # Plot training progress
    plt.figure(figsize=(10, 6))
    plt.plot(scores)
    plt.title('DQN Training Progress')
    plt.xlabel('Episode')
    plt.ylabel('Score')
    plt.savefig('dqn_training_progress.png')
    plt.show()

    # Plot moving average of scores for smoother visualization
    window_size = 100
    moving_avg = [np.mean(scores[max(0, i-window_size):(i+1)]) for i in range(len(scores))]

    plt.figure(figsize=(10, 6))
    plt.plot(moving_avg)
    plt.title('DQN Training Progress (Moving Average)')
    plt.xlabel('Episode')
    plt.ylabel('Average Score (over 100 episodes)')
    plt.savefig('dqn_training_progress_avg.png')
    plt.show()

    print("\nEvaluating agent...")
    eval_rewards = evaluate(env, agent, num_episodes=10, render=False)

    print("\nTraining complete!")

main_func()
# Out:
# Using device: cuda
# Training agent...
#   0%|          | 0/100000 [00:00<?, ?it/s]
# Episode 100/100000 | Average Score: -4866.95 | Epsilon: 0.9900
# Episode 200/100000 | Average Score: -4835.35 | Epsilon: 0.9802
# Episode 300/100000 | Average Score: -4768.80 | Epsilon: 0.9704
# Episode 400/100000 | Average Score: -4715.50 | Epsilon: 0.9608
# Episode 500/100000 | Average Score: -4751.45 | Epsilon: 0.9512
# Episode 600/100000 | Average Score: -4638.55 | Epsilon: 0.9418
# Episode 700/100000 | Average Score: -4564.85 | Epsilon: 0.9324
# Episode 800/100000 | Average Score: -4537.40 | Epsilon: 0.9231
# Episode 900/100000 | Average Score: -4464.30 | Epsilon: 0.9139
# Episode 1000/100000 | Average Score: -4385.65 | Epsilon: 0.9048
# Episode 1100/100000 | Average Score: -4334.75 | Epsilon: 0.8958
# Episode 1200/100000 | Average Score: -4314.10 | Epsilon: 0.8869
# Episode 1300/100000 | Average Score: -4244.45 | Epsilon: 0.8781
# Episode 1400/100000 | Average Score: -4157.20 | Epsilon: 0.8694
# Episode 1500/100000 | Average Score: -4160.30 | Epsilon: 0.8607
# Episode 1600/100000 | Average Score: -4120.85 | Epsilon: 0.8521
# Episode 1700/100000 | Average Score: -4070.70 | Epsilon: 0.8437
# Episode 1800/100000 | Average Score: -4010.45 | Epsilon: 0.8353
# Episode 1900/100000 | Average Score: -3938.10 | Epsilon: 0.8270
# Episode 2000/100000 | Average Score: -3953.35 | Epsilon: 0.8187
# Episode 2100/100000 | Average Score: -3931.25 | Epsilon: 0.8106
# Episode 2200/100000 | Average Score: -3904.50 | Epsilon: 0.8025
# Episode 2300/100000 | Average Score: -3806.65 | Epsilon: 0.7945
# Episode 2400/100000 | Average Score: -3785.00 | Epsilon: 0.7866
# Episode 2500/100000 | Average Score: -3769.10 | Epsilon: 0.7788
# Episode 2600/100000 | Average Score: -3732.70 | Epsilon: 0.7710
# Episode 2700/100000 | Average Score: -3668.65 | Epsilon: 0.7634
# Episode 2800/100000 | Average Score: -3700.45 | Epsilon: 0.7558
# Episode 2900/100000 | Average Score: -3683.45 | Epsilon: 0.7483
# Episode 3000/100000 | Average Score: -3543.60 | Epsilon: 0.7408
# Episode 3100/100000 | Average Score: -3499.85 | Epsilon: 0.7334
# Episode 3200/100000 | Average Score: -3530.30 | Epsilon: 0.7261
# Episode 3300/100000 | Average Score: -3535.20 | Epsilon: 0.7189
# Episode 3400/100000 | Average Score: -3500.75 | Epsilon: 0.7118
# Episode 3500/100000 | Average Score: -3455.50 | Epsilon: 0.7047
# Episode 3600/100000 | Average Score: -3387.20 | Epsilon: 0.6977
# Episode 3700/100000 | Average Score: -3394.25 | Epsilon: 0.6907
# Episode 3800/100000 | Average Score: -3328.90 | Epsilon: 0.6838
# Episode 3900/100000 | Average Score: -3385.60 | Epsilon: 0.6770
# Episode 4000/100000 | Average Score: -3279.95 | Epsilon: 0.6703
# Episode 4100/100000 | Average Score: -3260.00 | Epsilon: 0.6636
# Episode 4200/100000 | Average Score: -3235.85 | Epsilon: 0.6570
# Episode 4300/100000 | Average Score: -3216.75 | Epsilon: 0.6505
# Episode 4400/100000 | Average Score: -3151.70 | Epsilon: 0.6440
# Episode 4500/100000 | Average Score: -3200.20 | Epsilon: 0.6376
# Episode 4600/100000 | Average Score: -3074.10 | Epsilon: 0.6313
# Episode 4700/100000 | Average Score: -3106.45 | Epsilon: 0.6250
# Episode 4800/100000 | Average Score: -3051.55 | Epsilon: 0.6188
# Episode 4900/100000 | Average Score: -3026.95 | Epsilon: 0.6126
# Episode 5000/100000 | Average Score: -3012.20 | Epsilon: 0.6065
# Episode 5100/100000 | Average Score: -2966.90 | Epsilon: 0.6005
# Episode 5200/100000 | Average Score: -2929.50 | Epsilon: 0.5945
# Episode 5300/100000 | Average Score: -2909.20 | Epsilon: 0.5886
# Episode 5400/100000 | Average Score: -2889.10 | Epsilon: 0.5827
# Episode 5500/100000 | Average Score: -2856.20 | Epsilon: 0.5769
# Episode 5600/100000 | Average Score: -2839.45 | Epsilon: 0.5712
# Episode 5700/100000 | Average Score: -2839.80 | Epsilon: 0.5655
# Episode 5800/100000 | Average Score: -2765.10 | Epsilon: 0.5599
# Episode 5900/100000 | Average Score: -2725.75 | Epsilon: 0.5543
# Episode 6000/100000 | Average Score: -2721.25 | Epsilon: 0.5488
# Episode 6100/100000 | Average Score: -2687.50 | Epsilon: 0.5433
# Episode 6200/100000 | Average Score: -2689.70 | Epsilon: 0.5379
# Episode 6300/100000 | Average Score: -2627.30 | Epsilon: 0.5326
# Episode 6400/100000 | Average Score: -2584.95 | Epsilon: 0.5273
# Episode 6500/100000 | Average Score: -2608.95 | Epsilon: 0.5220
# Episode 6600/100000 | Average Score: -2580.20 | Epsilon: 0.5168
# Episode 6700/100000 | Average Score: -2558.05 | Epsilon: 0.5117
# Episode 6800/100000 | Average Score: -2495.65 | Epsilon: 0.5066
# Episode 6900/100000 | Average Score: -2478.30 | Epsilon: 0.5016
# Episode 7000/100000 | Average Score: -2446.50 | Epsilon: 0.4966
# Episode 7100/100000 | Average Score: -2456.00 | Epsilon: 0.4916
# Episode 7200/100000 | Average Score: -2416.65 | Epsilon: 0.4867
# Episode 7300/100000 | Average Score: -2407.75 | Epsilon: 0.4819
# Episode 7400/100000 | Average Score: -2367.40 | Epsilon: 0.4771
# Episode 7500/100000 | Average Score: -2377.80 | Epsilon: 0.4723
# Episode 7600/100000 | Average Score: -2349.30 | Epsilon: 0.4676
# Episode 7700/100000 | Average Score: -2335.05 | Epsilon: 0.4630
# Episode 7800/100000 | Average Score: -2239.45 | Epsilon: 0.4584
# Episode 7900/100000 | Average Score: -2294.05 | Epsilon: 0.4538
# Episode 8000/100000 | Average Score: -2206.90 | Epsilon: 0.4493
# Episode 8100/100000 | Average Score: -2206.15 | Epsilon: 0.4448
# Episode 8200/100000 | Average Score: -2159.30 | Epsilon: 0.4404
# Episode 8300/100000 | Average Score: -2154.65 | Epsilon: 0.4360
# Episode 8400/100000 | Average Score: -2142.70 | Epsilon: 0.4317
# Episode 8500/100000 | Average Score: -2140.15 | Epsilon: 0.4274
# Episode 8600/100000 | Average Score: -2107.25 | Epsilon: 0.4231
# Episode 8700/100000 | Average Score: -2074.25 | Epsilon: 0.4189
# Episode 8800/100000 | Average Score: -2063.35 | Epsilon: 0.4148
# Episode 8900/100000 | Average Score: -2043.15 | Epsilon: 0.4106
# Episode 9000/100000 | Average Score: -2060.30 | Epsilon: 0.4066
# Episode 9100/100000 | Average Score: -2019.30 | Epsilon: 0.4025
# Episode 9200/100000 | Average Score: -2014.45 | Epsilon: 0.3985
# Episode 9300/100000 | Average Score: -1985.05 | Epsilon: 0.3945
# Episode 9400/100000 | Average Score: -1925.55 | Epsilon: 0.3906
# Episode 9500/100000 | Average Score: -1920.15 | Epsilon: 0.3867
# Episode 9600/100000 | Average Score: -1939.55 | Epsilon: 0.3829
# Episode 9700/100000 | Average Score: -1877.45 | Epsilon: 0.3791
# Episode 9800/100000 | Average Score: -1910.85 | Epsilon: 0.3753
# Episode 9900/100000 | Average Score: -1873.40 | Epsilon: 0.3716
# Episode 10000/100000 | Average Score: -1849.20 | Epsilon: 0.3679
# Episode 10100/100000 | Average Score: -1831.50 | Epsilon: 0.3642
# Episode 10200/100000 | Average Score: -1809.75 | Epsilon: 0.3606
# Episode 10300/100000 | Average Score: -1817.65 | Epsilon: 0.3570
# Episode 10400/100000 | Average Score: -1802.90 | Epsilon: 0.3534
# Episode 10500/100000 | Average Score: -1783.05 | Epsilon: 0.3499
# Episode 10600/100000 | Average Score: -1764.65 | Epsilon: 0.3464
# Episode 10700/100000 | Average Score: -1749.10 | Epsilon: 0.3430
# Episode 10800/100000 | Average Score: -1757.15 | Epsilon: 0.3396
# Episode 10900/100000 | Average Score: -1731.35 | Epsilon: 0.3362
# Episode 11000/100000 | Average Score: -1697.40 | Epsilon: 0.3329
# Episode 11100/100000 | Average Score: -1655.15 | Epsilon: 0.3295
# Episode 11200/100000 | Average Score: -1675.35 | Epsilon: 0.3263
# Episode 11300/100000 | Average Score: -1631.20 | Epsilon: 0.3230
# Episode 11400/100000 | Average Score: -1621.60 | Epsilon: 0.3198
# Episode 11500/100000 | Average Score: -1625.20 | Epsilon: 0.3166
# Episode 11600/100000 | Average Score: -1583.20 | Epsilon: 0.3135
# Episode 11700/100000 | Average Score: -1608.20 | Epsilon: 0.3103
# Episode 11800/100000 | Average Score: -1578.35 | Epsilon: 0.3073
# Episode 11900/100000 | Average Score: -1554.25 | Epsilon: 0.3042
# Episode 12000/100000 | Average Score: -1537.45 | Epsilon: 0.3012
# Episode 12100/100000 | Average Score: -1535.70 | Epsilon: 0.2982
# Episode 12200/100000 | Average Score: -1514.30 | Epsilon: 0.2952
# Episode 12300/100000 | Average Score: -1533.05 | Epsilon: 0.2923
# Episode 12400/100000 | Average Score: -1462.25 | Epsilon: 0.2894
# Episode 12500/100000 | Average Score: -1461.70 | Epsilon: 0.2865
# Episode 12600/100000 | Average Score: -1454.05 | Epsilon: 0.2836
# Episode 12700/100000 | Average Score: -1444.95 | Epsilon: 0.2808
# Episode 12800/100000 | Average Score: -1416.45 | Epsilon: 0.2780
# Episode 12900/100000 | Average Score: -1441.70 | Epsilon: 0.2753
# Episode 13000/100000 | Average Score: -1393.80 | Epsilon: 0.2725
# Episode 13100/100000 | Average Score: -1402.30 | Epsilon: 0.2698
# Episode 13200/100000 | Average Score: -1378.65 | Epsilon: 0.2671
# Episode 13300/100000 | Average Score: -1388.25 | Epsilon: 0.2645
# Episode 13400/100000 | Average Score: -1345.70 | Epsilon: 0.2618
# Episode 13500/100000 | Average Score: -1358.25 | Epsilon: 0.2592
# Episode 13600/100000 | Average Score: -1345.00 | Epsilon: 0.2566
# Episode 13700/100000 | Average Score: -1323.95 | Epsilon: 0.2541
# Episode 13800/100000 | Average Score: -1313.45 | Epsilon: 0.2516
# Episode 13900/100000 | Average Score: -1299.90 | Epsilon: 0.2491
# Episode 14000/100000 | Average Score: -1289.60 | Epsilon: 0.2466
# Episode 14100/100000 | Average Score: -1251.25 | Epsilon: 0.2441
# Episode 14200/100000 | Average Score: -1256.35 | Epsilon: 0.2417
# Episode 14300/100000 | Average Score: -1242.70 | Epsilon: 0.2393
# Episode 14400/100000 | Average Score: -1233.55 | Epsilon: 0.2369
# Episode 14500/100000 | Average Score: -1226.05 | Epsilon: 0.2346
# Episode 14600/100000 | Average Score: -1231.65 | Epsilon: 0.2322
# Episode 14700/100000 | Average Score: -1209.30 | Epsilon: 0.2299
# Episode 14800/100000 | Average Score: -1193.45 | Epsilon: 0.2276
# Episode 14900/100000 | Average Score: -1162.75 | Epsilon: 0.2254
# Episode 15000/100000 | Average Score: -1169.60 | Epsilon: 0.2231
# Episode 15100/100000 | Average Score: -1158.30 | Epsilon: 0.2209
# Episode 15200/100000 | Average Score: -1131.60 | Epsilon: 0.2187
# Episode 15300/100000 | Average Score: -1142.55 | Epsilon: 0.2165
# Episode 15400/100000 | Average Score: -1135.20 | Epsilon: 0.2144
# Episode 15500/100000 | Average Score: -1130.45 | Epsilon: 0.2122
# Episode 15600/100000 | Average Score: -1112.10 | Epsilon: 0.2101
# Episode 15700/100000 | Average Score: -1105.75 | Epsilon: 0.2080
# Episode 15800/100000 | Average Score: -1118.15 | Epsilon: 0.2060
# Episode 15900/100000 | Average Score: -1099.55 | Epsilon: 0.2039
# Episode 16000/100000 | Average Score: -1072.10 | Epsilon: 0.2019
# Episode 16100/100000 | Average Score: -1038.20 | Epsilon: 0.1999
# Episode 16200/100000 | Average Score: -1037.20 | Epsilon: 0.1979
# Episode 16300/100000 | Average Score: -1044.55 | Epsilon: 0.1959
# Episode 16400/100000 | Average Score: -1034.55 | Epsilon: 0.1940
# Episode 16500/100000 | Average Score: -1017.70 | Epsilon: 0.1920
# Episode 16600/100000 | Average Score: -1026.90 | Epsilon: 0.1901
# Episode 16700/100000 | Average Score: -1016.50 | Epsilon: 0.1882
# Episode 16800/100000 | Average Score: -984.20 | Epsilon: 0.1864
# Episode 16900/100000 | Average Score: -996.15 | Epsilon: 0.1845
# Episode 17000/100000 | Average Score: -980.45 | Epsilon: 0.1827
# Episode 17100/100000 | Average Score: -965.80 | Epsilon: 0.1809
# Episode 17200/100000 | Average Score: -957.40 | Epsilon: 0.1791
# Episode 17300/100000 | Average Score: -960.55 | Epsilon: 0.1773
# Episode 17400/100000 | Average Score: -947.85 | Epsilon: 0.1755
# Episode 17500/100000 | Average Score: -935.40 | Epsilon: 0.1738
# Episode 17600/100000 | Average Score: -918.05 | Epsilon: 0.1720
# Episode 17700/100000 | Average Score: -911.80 | Epsilon: 0.1703
# Episode 17800/100000 | Average Score: -902.00 | Epsilon: 0.1686
# Episode 17900/100000 | Average Score: -919.00 | Epsilon: 0.1669
# Episode 18000/100000 | Average Score: -923.25 | Epsilon: 0.1653
# Episode 18100/100000 | Average Score: -879.80 | Epsilon: 0.1636
# Episode 18200/100000 | Average Score: -881.60 | Epsilon: 0.1620
# Episode 18300/100000 | Average Score: -878.00 | Epsilon: 0.1604
# Episode 18400/100000 | Average Score: -869.45 | Epsilon: 0.1588
# Episode 18500/100000 | Average Score: -870.40 | Epsilon: 0.1572
# Episode 18600/100000 | Average Score: -865.75 | Epsilon: 0.1557
# Episode 18700/100000 | Average Score: -838.90 | Epsilon: 0.1541
# Episode 18800/100000 | Average Score: -832.85 | Epsilon: 0.1526
# Episode 18900/100000 | Average Score: -824.70 | Epsilon: 0.1511
# Episode 19000/100000 | Average Score: -820.75 | Epsilon: 0.1496
# Episode 19100/100000 | Average Score: -807.15 | Epsilon: 0.1481
# Episode 19200/100000 | Average Score: -801.20 | Epsilon: 0.1466
# Episode 19300/100000 | Average Score: -807.05 | Epsilon: 0.1451
# Episode 19400/100000 | Average Score: -790.85 | Epsilon: 0.1437
# Episode 19500/100000 | Average Score: -784.55 | Epsilon: 0.1423
# Episode 19600/100000 | Average Score: -791.15 | Epsilon: 0.1408
# Episode 19700/100000 | Average Score: -795.25 | Epsilon: 0.1394
# Episode 19800/100000 | Average Score: -767.40 | Epsilon: 0.1381
# Episode 19900/100000 | Average Score: -738.70 | Epsilon: 0.1367
# Episode 20000/100000 | Average Score: -765.65 | Epsilon: 0.1353
# Episode 20100/100000 | Average Score: -739.20 | Epsilon: 0.1340
# Episode 20200/100000 | Average Score: -746.55 | Epsilon: 0.1326
# Episode 20300/100000 | Average Score: -734.05 | Epsilon: 0.1313
# Episode 20400/100000 | Average Score: -725.75 | Epsilon: 0.1300
# Episode 20500/100000 | Average Score: -718.70 | Epsilon: 0.1287
# Episode 20600/100000 | Average Score: -709.35 | Epsilon: 0.1274
# Episode 20700/100000 | Average Score: -729.40 | Epsilon: 0.1262
# Episode 20800/100000 | Average Score: -716.25 | Epsilon: 0.1249
# Episode 20900/100000 | Average Score: -718.70 | Epsilon: 0.1237
# Episode 21000/100000 | Average Score: -712.20 | Epsilon: 0.1224
# Episode 21100/100000 | Average Score: -675.10 | Epsilon: 0.1212
# Episode 21200/100000 | Average Score: -680.65 | Epsilon: 0.1200
# Episode 21300/100000 | Average Score: -685.30 | Epsilon: 0.1188
# Episode 21400/100000 | Average Score: -681.25 | Epsilon: 0.1176
# Episode 21500/100000 | Average Score: -660.10 | Epsilon: 0.1165
# Episode 21600/100000 | Average Score: -647.95 | Epsilon: 0.1153
# Episode 21700/100000 | Average Score: -645.10 | Epsilon: 0.1142
# Episode 21800/100000 | Average Score: -645.50 | Epsilon: 0.1130
# Episode 21900/100000 | Average Score: -634.15 | Epsilon: 0.1119
# Episode 22000/100000 | Average Score: -644.95 | Epsilon: 0.1108
# Episode 22100/100000 | Average Score: -640.40 | Epsilon: 0.1097
# Episode 22200/100000 | Average Score: -629.40 | Epsilon: 0.1086
# Episode 22300/100000 | Average Score: -623.15 | Epsilon: 0.1075
# Episode 22400/100000 | Average Score: -616.25 | Epsilon: 0.1064
# Episode 22500/100000 | Average Score: -619.20 | Epsilon: 0.1054
# Episode 22600/100000 | Average Score: -597.95 | Epsilon: 0.1043
# Episode 22700/100000 | Average Score: -616.55 | Epsilon: 0.1033
# Episode 22800/100000 | Average Score: -604.00 | Epsilon: 0.1023
# Episode 22900/100000 | Average Score: -584.75 | Epsilon: 0.1013
# Episode 23000/100000 | Average Score: -594.70 | Epsilon: 0.1002
# Episode 23100/100000 | Average Score: -586.35 | Epsilon: 0.0992
# Episode 23200/100000 | Average Score: -577.45 | Epsilon: 0.0983
# Episode 23300/100000 | Average Score: -594.50 | Epsilon: 0.0973
# Episode 23400/100000 | Average Score: -582.35 | Epsilon: 0.0963
# Episode 23500/100000 | Average Score: -559.65 | Epsilon: 0.0954
# Episode 23600/100000 | Average Score: -564.95 | Epsilon: 0.0944
# Episode 23700/100000 | Average Score: -555.90 | Epsilon: 0.0935
# Episode 23800/100000 | Average Score: -542.35 | Epsilon: 0.0925
# Episode 23900/100000 | Average Score: -542.25 | Epsilon: 0.0916
# Episode 24000/100000 | Average Score: -535.25 | Epsilon: 0.0907
# Episode 24100/100000 | Average Score: -527.45 | Epsilon: 0.0898
# Episode 24200/100000 | Average Score: -533.05 | Epsilon: 0.0889
# Episode 24300/100000 | Average Score: -532.25 | Epsilon: 0.0880
# Episode 24400/100000 | Average Score: -519.15 | Epsilon: 0.0872
# Episode 24500/100000 | Average Score: -514.80 | Epsilon: 0.0863
# Episode 24600/100000 | Average Score: -505.45 | Epsilon: 0.0854
# Episode 24700/100000 | Average Score: -507.15 | Epsilon: 0.0846
# Episode 24800/100000 | Average Score: -508.65 | Epsilon: 0.0837
# Episode 24900/100000 | Average Score: -491.50 | Epsilon: 0.0829
# Episode 25000/100000 | Average Score: -506.10 | Epsilon: 0.0821
# Episode 25100/100000 | Average Score: -490.50 | Epsilon: 0.0813
# Episode 25200/100000 | Average Score: -491.60 | Epsilon: 0.0804
# Episode 25300/100000 | Average Score: -472.35 | Epsilon: 0.0796
# Episode 25400/100000 | Average Score: -492.55 | Epsilon: 0.0789
# Episode 25500/100000 | Average Score: -485.15 | Epsilon: 0.0781
# Episode 25600/100000 | Average Score: -479.65 | Epsilon: 0.0773
# Episode 25700/100000 | Average Score: -479.20 | Epsilon: 0.0765
# Episode 25800/100000 | Average Score: -465.30 | Epsilon: 0.0758
# Episode 25900/100000 | Average Score: -458.20 | Epsilon: 0.0750
# Episode 26000/100000 | Average Score: -462.70 | Epsilon: 0.0743
# Episode 26100/100000 | Average Score: -460.05 | Epsilon: 0.0735
# Episode 26200/100000 | Average Score: -456.55 | Epsilon: 0.0728
# Episode 26300/100000 | Average Score: -453.65 | Epsilon: 0.0721
# Episode 26400/100000 | Average Score: -423.75 | Epsilon: 0.0714
# Episode 26500/100000 | Average Score: -445.35 | Epsilon: 0.0706
# Episode 26600/100000 | Average Score: -446.25 | Epsilon: 0.0699
# Episode 26700/100000 | Average Score: -446.80 | Epsilon: 0.0692
# Episode 26800/100000 | Average Score: -429.95 | Epsilon: 0.0686
# Episode 26900/100000 | Average Score: -429.75 | Epsilon: 0.0679
# Episode 27000/100000 | Average Score: -421.70 | Epsilon: 0.0672
# Episode 27100/100000 | Average Score: -424.70 | Epsilon: 0.0665
# Episode 27200/100000 | Average Score: -416.45 | Epsilon: 0.0659
# Episode 27300/100000 | Average Score: -426.40 | Epsilon: 0.0652
# Episode 27400/100000 | Average Score: -423.80 | Epsilon: 0.0646
# Episode 27500/100000 | Average Score: -413.60 | Epsilon: 0.0639
# Episode 27600/100000 | Average Score: -405.70 | Epsilon: 0.0633
# Episode 27700/100000 | Average Score: -400.80 | Epsilon: 0.0627
# Episode 27800/100000 | Average Score: -402.15 | Epsilon: 0.0620
# Episode 27900/100000 | Average Score: -394.85 | Epsilon: 0.0614
# Episode 28000/100000 | Average Score: -395.45 | Epsilon: 0.0608
# Episode 28100/100000 | Average Score: -386.60 | Epsilon: 0.0602
# Episode 28200/100000 | Average Score: -390.45 | Epsilon: 0.0596
# Episode 28300/100000 | Average Score: -389.60 | Epsilon: 0.0590
# Episode 28400/100000 | Average Score: -388.95 | Epsilon: 0.0584
# Episode 28500/100000 | Average Score: -390.00 | Epsilon: 0.0578
# Episode 28600/100000 | Average Score: -374.90 | Epsilon: 0.0573
# Episode 28700/100000 | Average Score: -370.05 | Epsilon: 0.0567
# Episode 28800/100000 | Average Score: -365.15 | Epsilon: 0.0561
# Episode 28900/100000 | Average Score: -368.75 | Epsilon: 0.0556
# Episode 29000/100000 | Average Score: -363.80 | Epsilon: 0.0550
# Episode 29100/100000 | Average Score: -360.30 | Epsilon: 0.0545
# Episode 29200/100000 | Average Score: -368.95 | Epsilon: 0.0539
# Episode 29300/100000 | Average Score: -364.95 | Epsilon: 0.0534
# Episode 29400/100000 | Average Score: -358.60 | Epsilon: 0.0529
# Episode 29500/100000 | Average Score: -355.85 | Epsilon: 0.0523
# Episode 29600/100000 | Average Score: -350.70 | Epsilon: 0.0518
# Episode 29700/100000 | Average Score: -349.00 | Epsilon: 0.0513
# Episode 29800/100000 | Average Score: -348.75 | Epsilon: 0.0508
# Episode 29900/100000 | Average Score: -347.85 | Epsilon: 0.0503
# Episode 30000/100000 | Average Score: -346.05 | Epsilon: 0.0498
# Episode 30100/100000 | Average Score: -341.80 | Epsilon: 0.0493
# Episode 30200/100000 | Average Score: -339.65 | Epsilon: 0.0488
# Episode 30300/100000 | Average Score: -333.65 | Epsilon: 0.0483
# Episode 30400/100000 | Average Score: -332.65 | Epsilon: 0.0478
# Episode 30500/100000 | Average Score: -328.45 | Epsilon: 0.0474
# Episode 30600/100000 | Average Score: -322.00 | Epsilon: 0.0469
# Episode 30700/100000 | Average Score: -339.15 | Epsilon: 0.0464
# Episode 30800/100000 | Average Score: -318.55 | Epsilon: 0.0460
# Episode 30900/100000 | Average Score: -311.40 | Epsilon: 0.0455
# Episode 31000/100000 | Average Score: -318.80 | Epsilon: 0.0450
# Episode 31100/100000 | Average Score: -322.30 | Epsilon: 0.0446
# Episode 31200/100000 | Average Score: -316.25 | Epsilon: 0.0442
# Episode 31300/100000 | Average Score: -320.80 | Epsilon: 0.0437
# Episode 31400/100000 | Average Score: -313.20 | Epsilon: 0.0433
# Episode 31500/100000 | Average Score: -304.90 | Epsilon: 0.0428
# Episode 31600/100000 | Average Score: -305.40 | Epsilon: 0.0424
# Episode 31700/100000 | Average Score: -305.85 | Epsilon: 0.0420
# Episode 31800/100000 | Average Score: -305.70 | Epsilon: 0.0416
# Episode 31900/100000 | Average Score: -296.00 | Epsilon: 0.0412
# Episode 32000/100000 | Average Score: -288.00 | Epsilon: 0.0408
# Episode 32100/100000 | Average Score: -294.05 | Epsilon: 0.0404
# Episode 32200/100000 | Average Score: -297.15 | Epsilon: 0.0399
# Episode 32300/100000 | Average Score: -295.65 | Epsilon: 0.0396
# Episode 32400/100000 | Average Score: -287.40 | Epsilon: 0.0392
# Episode 32500/100000 | Average Score: -292.00 | Epsilon: 0.0388
# Episode 32600/100000 | Average Score: -281.65 | Epsilon: 0.0384
# Episode 32700/100000 | Average Score: -286.60 | Epsilon: 0.0380
# Episode 32800/100000 | Average Score: -284.55 | Epsilon: 0.0376
# Episode 32900/100000 | Average Score: -288.10 | Epsilon: 0.0372
# Episode 33000/100000 | Average Score: -289.15 | Epsilon: 0.0369
# Episode 33100/100000 | Average Score: -276.50 | Epsilon: 0.0365
# Episode 33200/100000 | Average Score: -271.40 | Epsilon: 0.0361
# Episode 33300/100000 | Average Score: -276.10 | Epsilon: 0.0358
# Episode 33400/100000 | Average Score: -278.20 | Epsilon: 0.0354
# Episode 33500/100000 | Average Score: -270.45 | Epsilon: 0.0351
# Episode 33600/100000 | Average Score: -264.40 | Epsilon: 0.0347
# Episode 33700/100000 | Average Score: -265.85 | Epsilon: 0.0344
# Episode 33800/100000 | Average Score: -272.30 | Epsilon: 0.0340
# Episode 33900/100000 | Average Score: -268.05 | Epsilon: 0.0337
# Episode 34000/100000 | Average Score: -267.45 | Epsilon: 0.0334
# Episode 34100/100000 | Average Score: -258.15 | Epsilon: 0.0330
# Episode 34200/100000 | Average Score: -262.60 | Epsilon: 0.0327
# Episode 34300/100000 | Average Score: -252.40 | Epsilon: 0.0324
# Episode 34400/100000 | Average Score: -254.55 | Epsilon: 0.0321
# Episode 34500/100000 | Average Score: -257.80 | Epsilon: 0.0317
# Episode 34600/100000 | Average Score: -255.20 | Epsilon: 0.0314
# Episode 34700/100000 | Average Score: -252.65 | Epsilon: 0.0311
# Episode 34800/100000 | Average Score: -247.00 | Epsilon: 0.0308
# Episode 34900/100000 | Average Score: -245.10 | Epsilon: 0.0305
# Episode 35000/100000 | Average Score: -245.00 | Epsilon: 0.0302
# Episode 35100/100000 | Average Score: -243.05 | Epsilon: 0.0299
# Episode 35200/100000 | Average Score: -245.50 | Epsilon: 0.0296
# Episode 35300/100000 | Average Score: -241.50 | Epsilon: 0.0293
# Episode 35400/100000 | Average Score: -243.70 | Epsilon: 0.0290
# Episode 35500/100000 | Average Score: -244.10 | Epsilon: 0.0287
# Episode 35600/100000 | Average Score: -242.55 | Epsilon: 0.0284
# Episode 35700/100000 | Average Score: -231.45 | Epsilon: 0.0282
# Episode 35800/100000 | Average Score: -231.30 | Epsilon: 0.0279
# Episode 35900/100000 | Average Score: -236.20 | Epsilon: 0.0276
# Episode 36000/100000 | Average Score: -232.30 | Epsilon: 0.0273
# Episode 36100/100000 | Average Score: -231.90 | Epsilon: 0.0270
# Episode 36200/100000 | Average Score: -230.70 | Epsilon: 0.0268
# Episode 36300/100000 | Average Score: -230.70 | Epsilon: 0.0265
# Episode 36400/100000 | Average Score: -227.80 | Epsilon: 0.0262
# Episode 36500/100000 | Average Score: -232.05 | Epsilon: 0.0260
# Episode 36600/100000 | Average Score: -226.35 | Epsilon: 0.0257
# Episode 36700/100000 | Average Score: -223.30 | Epsilon: 0.0255
# Episode 36800/100000 | Average Score: -222.65 | Epsilon: 0.0252
# Episode 36900/100000 | Average Score: -225.50 | Epsilon: 0.0250
# Episode 37000/100000 | Average Score: -216.70 | Epsilon: 0.0247
# Episode 37100/100000 | Average Score: -221.00 | Epsilon: 0.0245
# Episode 37200/100000 | Average Score: -213.00 | Epsilon: 0.0242
# Episode 37300/100000 | Average Score: -216.30 | Epsilon: 0.0240
# Episode 37400/100000 | Average Score: -213.35 | Epsilon: 0.0237
# Episode 37500/100000 | Average Score: -217.75 | Epsilon: 0.0235
# Episode 37600/100000 | Average Score: -206.90 | Epsilon: 0.0233
# Episode 37700/100000 | Average Score: -210.45 | Epsilon: 0.0230
# Episode 37800/100000 | Average Score: -209.05 | Epsilon: 0.0228
# Episode 37900/100000 | Average Score: -209.45 | Epsilon: 0.0226
# Episode 38000/100000 | Average Score: -205.75 | Epsilon: 0.0224
# Episode 38100/100000 | Average Score: -208.80 | Epsilon: 0.0221
# Episode 38200/100000 | Average Score: -208.50 | Epsilon: 0.0219
# Episode 38300/100000 | Average Score: -203.00 | Epsilon: 0.0217
# Episode 38400/100000 | Average Score: -209.00 | Epsilon: 0.0215
# Episode 38500/100000 | Average Score: -201.90 | Epsilon: 0.0213
# Episode 38600/100000 | Average Score: -204.25 | Epsilon: 0.0211
# Episode 38700/100000 | Average Score: -204.90 | Epsilon: 0.0209
# Episode 38800/100000 | Average Score: -199.90 | Epsilon: 0.0206
# Episode 38900/100000 | Average Score: -200.15 | Epsilon: 0.0204
# Episode 39000/100000 | Average Score: -196.20 | Epsilon: 0.0202
# Episode 39100/100000 | Average Score: -205.65 | Epsilon: 0.0200
# Episode 39200/100000 | Average Score: -198.00 | Epsilon: 0.0198
# Episode 39300/100000 | Average Score: -195.95 | Epsilon: 0.0196
# Episode 39400/100000 | Average Score: -194.90 | Epsilon: 0.0194
# Episode 39500/100000 | Average Score: -192.60 | Epsilon: 0.0193
# Episode 39600/100000 | Average Score: -193.35 | Epsilon: 0.0191
# Episode 39700/100000 | Average Score: -190.75 | Epsilon: 0.0189
# Episode 39800/100000 | Average Score: -191.70 | Epsilon: 0.0187
# Episode 39900/100000 | Average Score: -187.20 | Epsilon: 0.0185
# Episode 40000/100000 | Average Score: -189.75 | Epsilon: 0.0183
# Episode 40100/100000 | Average Score: -186.60 | Epsilon: 0.0181
# Episode 40200/100000 | Average Score: -190.65 | Epsilon: 0.0179
# Episode 40300/100000 | Average Score: -186.05 | Epsilon: 0.0178
# Episode 40400/100000 | Average Score: -190.75 | Epsilon: 0.0176
# Episode 40500/100000 | Average Score: -192.85 | Epsilon: 0.0174
# Episode 40600/100000 | Average Score: -185.30 | Epsilon: 0.0172
# Episode 40700/100000 | Average Score: -187.25 | Epsilon: 0.0171
# Episode 40800/100000 | Average Score: -182.55 | Epsilon: 0.0169
# Episode 40900/100000 | Average Score: -180.75 | Epsilon: 0.0167
# Episode 41000/100000 | Average Score: -180.15 | Epsilon: 0.0166
# Episode 41100/100000 | Average Score: -177.50 | Epsilon: 0.0164
# Episode 41200/100000 | Average Score: -177.55 | Epsilon: 0.0162
# Episode 41300/100000 | Average Score: -181.90 | Epsilon: 0.0161
# Episode 41400/100000 | Average Score: -179.15 | Epsilon: 0.0159
# Episode 41500/100000 | Average Score: -175.85 | Epsilon: 0.0158
# Episode 41600/100000 | Average Score: -176.10 | Epsilon: 0.0156
# Episode 41700/100000 | Average Score: -173.65 | Epsilon: 0.0154
# Episode 41800/100000 | Average Score: -176.30 | Epsilon: 0.0153
# Episode 41900/100000 | Average Score: -171.25 | Epsilon: 0.0151
# Episode 42000/100000 | Average Score: -176.35 | Epsilon: 0.0150
# Episode 42100/100000 | Average Score: -168.90 | Epsilon: 0.0148
# Episode 42200/100000 | Average Score: -170.25 | Epsilon: 0.0147
# Episode 42300/100000 | Average Score: -173.30 | Epsilon: 0.0145
# Episode 42400/100000 | Average Score: -173.45 | Epsilon: 0.0144
# Episode 42500/100000 | Average Score: -169.60 | Epsilon: 0.0143
# Episode 42600/100000 | Average Score: -167.90 | Epsilon: 0.0141
# Episode 42700/100000 | Average Score: -167.55 | Epsilon: 0.0140
# Episode 42800/100000 | Average Score: -168.45 | Epsilon: 0.0138
# Episode 42900/100000 | Average Score: -166.95 | Epsilon: 0.0137
# Episode 43000/100000 | Average Score: -165.35 | Epsilon: 0.0136
# Episode 43100/100000 | Average Score: -167.60 | Epsilon: 0.0134
# Episode 43200/100000 | Average Score: -168.15 | Epsilon: 0.0133
# Episode 43300/100000 | Average Score: -162.35 | Epsilon: 0.0132
# Episode 43400/100000 | Average Score: -161.70 | Epsilon: 0.0130
# Episode 43500/100000 | Average Score: -167.65 | Epsilon: 0.0129
# Episode 43600/100000 | Average Score: -167.15 | Epsilon: 0.0128
# Episode 43700/100000 | Average Score: -158.05 | Epsilon: 0.0126
# Episode 43800/100000 | Average Score: -160.30 | Epsilon: 0.0125
# Episode 43900/100000 | Average Score: -159.40 | Epsilon: 0.0124
# Episode 44000/100000 | Average Score: -159.15 | Epsilon: 0.0123
# Episode 44100/100000 | Average Score: -160.35 | Epsilon: 0.0122
# Episode 44200/100000 | Average Score: -163.40 | Epsilon: 0.0120
# Episode 44300/100000 | Average Score: -157.35 | Epsilon: 0.0119
# Episode 44400/100000 | Average Score: -158.75 | Epsilon: 0.0118
# Episode 44500/100000 | Average Score: -155.45 | Epsilon: 0.0117
# Episode 44600/100000 | Average Score: -154.10 | Epsilon: 0.0116
# Episode 44700/100000 | Average Score: -158.70 | Epsilon: 0.0114
# Episode 44800/100000 | Average Score: -157.60 | Epsilon: 0.0113
# Episode 44900/100000 | Average Score: -155.05 | Epsilon: 0.0112
# Episode 45000/100000 | Average Score: -155.35 | Epsilon: 0.0111
# Episode 45100/100000 | Average Score: -150.50 | Epsilon: 0.0110
# Episode 45200/100000 | Average Score: -152.65 | Epsilon: 0.0109
# Episode 45300/100000 | Average Score: -151.50 | Epsilon: 0.0108
# Episode 45400/100000 | Average Score: -152.55 | Epsilon: 0.0107
# Episode 45500/100000 | Average Score: -150.40 | Epsilon: 0.0106
# Episode 45600/100000 | Average Score: -152.45 | Epsilon: 0.0105
# Episode 45700/100000 | Average Score: -153.80 | Epsilon: 0.0104
# Episode 45800/100000 | Average Score: -153.45 | Epsilon: 0.0103
# Episode 45900/100000 | Average Score: -146.05 | Epsilon: 0.0102
# Episode 46000/100000 | Average Score: -150.10 | Epsilon: 0.0100
# Episode 46100/100000 | Average Score: -150.55 | Epsilon: 0.0100
# Episode 46200/100000 | Average Score: -145.65 | Epsilon: 0.0100
# Episode 46300/100000 | Average Score: -149.20 | Epsilon: 0.0100
# Episode 46400/100000 | Average Score: -146.35 | Epsilon: 0.0100
# Episode 46500/100000 | Average Score: -148.55 | Epsilon: 0.0100
# Episode 46600/100000 | Average Score: -147.00 | Epsilon: 0.0100
# Episode 46700/100000 | Average Score: -149.45 | Epsilon: 0.0100
# Episode 46800/100000 | Average Score: -151.55 | Epsilon: 0.0100
# Episode 46900/100000 | Average Score: -148.65 | Epsilon: 0.0100
# Episode 47000/100000 | Average Score: -145.85 | Epsilon: 0.0100
# Episode 47100/100000 | Average Score: -149.70 | Epsilon: 0.0100
# Episode 47200/100000 | Average Score: -151.85 | Epsilon: 0.0100
# Episode 47300/100000 | Average Score: -146.30 | Epsilon: 0.0100
# Episode 47400/100000 | Average Score: -150.75 | Epsilon: 0.0100
# Episode 47500/100000 | Average Score: -149.90 | Epsilon: 0.0100
# Episode 47600/100000 | Average Score: -150.20 | Epsilon: 0.0100
# Episode 47700/100000 | Average Score: -151.30 | Epsilon: 0.0100
# Episode 47800/100000 | Average Score: -145.45 | Epsilon: 0.0100
# Episode 47900/100000 | Average Score: -150.30 | Epsilon: 0.0100
# Episode 48000/100000 | Average Score: -151.70 | Epsilon: 0.0100
# Episode 48100/100000 | Average Score: -147.60 | Epsilon: 0.0100
# Episode 48200/100000 | Average Score: -146.90 | Epsilon: 0.0100
# Episode 48300/100000 | Average Score: -146.30 | Epsilon: 0.0100
# Episode 48400/100000 | Average Score: -144.65 | Epsilon: 0.0100
# Episode 48500/100000 | Average Score: -151.10 | Epsilon: 0.0100
# Episode 48600/100000 | Average Score: -151.00 | Epsilon: 0.0100
# Episode 48700/100000 | Average Score: -151.90 | Epsilon: 0.0100
# Episode 48800/100000 | Average Score: -147.60 | Epsilon: 0.0100
# Episode 48900/100000 | Average Score: -148.35 | Epsilon: 0.0100
# Episode 49000/100000 | Average Score: -149.00 | Epsilon: 0.0100
# Episode 49100/100000 | Average Score: -149.80 | Epsilon: 0.0100
# Episode 49200/100000 | Average Score: -150.30 | Epsilon: 0.0100
# Episode 49300/100000 | Average Score: -148.70 | Epsilon: 0.0100
# Episode 49400/100000 | Average Score: -146.25 | Epsilon: 0.0100
# Episode 49500/100000 | Average Score: -145.55 | Epsilon: 0.0100
# Episode 49600/100000 | Average Score: -151.05 | Epsilon: 0.0100
# Episode 49700/100000 | Average Score: -147.95 | Epsilon: 0.0100
# Episode 49800/100000 | Average Score: -148.10 | Epsilon: 0.0100
# Episode 49900/100000 | Average Score: -149.10 | Epsilon: 0.0100
# Episode 50000/100000 | Average Score: -148.65 | Epsilon: 0.0100
# Episode 50100/100000 | Average Score: -145.60 | Epsilon: 0.0100
# Episode 50200/100000 | Average Score: -151.75 | Epsilon: 0.0100
# Episode 50300/100000 | Average Score: -147.00 | Epsilon: 0.0100
# Episode 50400/100000 | Average Score: -153.10 | Epsilon: 0.0100
# Episode 50500/100000 | Average Score: -148.80 | Epsilon: 0.0100
# Episode 50600/100000 | Average Score: -146.55 | Epsilon: 0.0100
# Episode 50700/100000 | Average Score: -145.90 | Epsilon: 0.0100
# Episode 50800/100000 | Average Score: -148.15 | Epsilon: 0.0100
# Episode 50900/100000 | Average Score: -148.70 | Epsilon: 0.0100
# Episode 51000/100000 | Average Score: -149.95 | Epsilon: 0.0100
# Episode 51100/100000 | Average Score: -148.65 | Epsilon: 0.0100
# Episode 51200/100000 | Average Score: -153.55 | Epsilon: 0.0100
# Episode 51300/100000 | Average Score: -154.40 | Epsilon: 0.0100
# Episode 51400/100000 | Average Score: -152.70 | Epsilon: 0.0100
# Episode 51500/100000 | Average Score: -152.95 | Epsilon: 0.0100
# Episode 51600/100000 | Average Score: -152.90 | Epsilon: 0.0100
# Episode 51700/100000 | Average Score: -145.55 | Epsilon: 0.0100
# Episode 51800/100000 | Average Score: -145.80 | Epsilon: 0.0100
# Episode 51900/100000 | Average Score: -148.75 | Epsilon: 0.0100
# Episode 52000/100000 | Average Score: -149.85 | Epsilon: 0.0100
# Episode 52100/100000 | Average Score: -147.70 | Epsilon: 0.0100
# Episode 52200/100000 | Average Score: -148.90 | Epsilon: 0.0100
# Episode 52300/100000 | Average Score: -148.25 | Epsilon: 0.0100
# Episode 52400/100000 | Average Score: -151.10 | Epsilon: 0.0100
# Episode 52500/100000 | Average Score: -149.75 | Epsilon: 0.0100
# Episode 52600/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 52700/100000 | Average Score: -151.20 | Epsilon: 0.0100
# Episode 52800/100000 | Average Score: -148.80 | Epsilon: 0.0100
# Episode 52900/100000 | Average Score: -146.50 | Epsilon: 0.0100
# Episode 53000/100000 | Average Score: -148.50 | Epsilon: 0.0100
# Episode 53100/100000 | Average Score: -148.35 | Epsilon: 0.0100
# Episode 53200/100000 | Average Score: -147.80 | Epsilon: 0.0100
# Episode 53300/100000 | Average Score: -145.80 | Epsilon: 0.0100
# Episode 53400/100000 | Average Score: -147.05 | Epsilon: 0.0100
# Episode 53500/100000 | Average Score: -150.35 | Epsilon: 0.0100
# Episode 53600/100000 | Average Score: -144.90 | Epsilon: 0.0100
# Episode 53700/100000 | Average Score: -148.75 | Epsilon: 0.0100
# Episode 53800/100000 | Average Score: -151.10 | Epsilon: 0.0100
# Episode 53900/100000 | Average Score: -149.60 | Epsilon: 0.0100
# Episode 54000/100000 | Average Score: -145.00 | Epsilon: 0.0100
# Episode 54100/100000 | Average Score: -151.25 | Epsilon: 0.0100
# Episode 54200/100000 | Average Score: -147.10 | Epsilon: 0.0100
# Episode 54300/100000 | Average Score: -147.25 | Epsilon: 0.0100
# Episode 54400/100000 | Average Score: -150.10 | Epsilon: 0.0100
# Episode 54500/100000 | Average Score: -149.75 | Epsilon: 0.0100
# Episode 54600/100000 | Average Score: -151.25 | Epsilon: 0.0100
# Episode 54700/100000 | Average Score: -149.35 | Epsilon: 0.0100
# Episode 54800/100000 | Average Score: -147.60 | Epsilon: 0.0100
# Episode 54900/100000 | Average Score: -153.45 | Epsilon: 0.0100
# Episode 55000/100000 | Average Score: -151.75 | Epsilon: 0.0100
# Episode 55100/100000 | Average Score: -147.70 | Epsilon: 0.0100
# Episode 55200/100000 | Average Score: -148.65 | Epsilon: 0.0100
# Episode 55300/100000 | Average Score: -148.80 | Epsilon: 0.0100
# Episode 55400/100000 | Average Score: -153.95 | Epsilon: 0.0100
# Episode 55500/100000 | Average Score: -150.85 | Epsilon: 0.0100
# Episode 55600/100000 | Average Score: -143.60 | Epsilon: 0.0100
# Episode 55700/100000 | Average Score: -153.35 | Epsilon: 0.0100
# Episode 55800/100000 | Average Score: -147.85 | Epsilon: 0.0100
# Episode 55900/100000 | Average Score: -148.90 | Epsilon: 0.0100
# Episode 56000/100000 | Average Score: -148.95 | Epsilon: 0.0100
# Episode 56100/100000 | Average Score: -148.90 | Epsilon: 0.0100
# Episode 56200/100000 | Average Score: -150.00 | Epsilon: 0.0100
# Episode 56300/100000 | Average Score: -151.70 | Epsilon: 0.0100
# Episode 56400/100000 | Average Score: -148.35 | Epsilon: 0.0100
# Episode 56500/100000 | Average Score: -147.15 | Epsilon: 0.0100
# Episode 56600/100000 | Average Score: -149.50 | Epsilon: 0.0100
# Episode 56700/100000 | Average Score: -150.60 | Epsilon: 0.0100
# Episode 56800/100000 | Average Score: -148.15 | Epsilon: 0.0100
# Episode 56900/100000 | Average Score: -146.60 | Epsilon: 0.0100
# Episode 57000/100000 | Average Score: -150.25 | Epsilon: 0.0100
# Episode 57100/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 57200/100000 | Average Score: -148.25 | Epsilon: 0.0100
# Episode 57300/100000 | Average Score: -146.65 | Epsilon: 0.0100
# Episode 57400/100000 | Average Score: -148.60 | Epsilon: 0.0100
# Episode 57500/100000 | Average Score: -148.50 | Epsilon: 0.0100
# Episode 57600/100000 | Average Score: -146.00 | Epsilon: 0.0100
# Episode 57700/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 57800/100000 | Average Score: -151.80 | Epsilon: 0.0100
# Episode 57900/100000 | Average Score: -148.50 | Epsilon: 0.0100
# Episode 58000/100000 | Average Score: -148.15 | Epsilon: 0.0100
# Episode 58100/100000 | Average Score: -151.75 | Epsilon: 0.0100
# Episode 58200/100000 | Average Score: -145.35 | Epsilon: 0.0100
# Episode 58300/100000 | Average Score: -148.30 | Epsilon: 0.0100
# Episode 58400/100000 | Average Score: -150.65 | Epsilon: 0.0100
# Episode 58500/100000 | Average Score: -150.90 | Epsilon: 0.0100
# Episode 58600/100000 | Average Score: -149.60 | Epsilon: 0.0100
# Episode 58700/100000 | Average Score: -149.45 | Epsilon: 0.0100
# Episode 58800/100000 | Average Score: -149.60 | Epsilon: 0.0100
# Episode 58900/100000 | Average Score: -145.90 | Epsilon: 0.0100
# Episode 59000/100000 | Average Score: -150.80 | Epsilon: 0.0100
# Episode 59100/100000 | Average Score: -146.60 | Epsilon: 0.0100
# Episode 59200/100000 | Average Score: -149.90 | Epsilon: 0.0100
# Episode 59300/100000 | Average Score: -147.00 | Epsilon: 0.0100
# Episode 59400/100000 | Average Score: -146.55 | Epsilon: 0.0100
# Episode 59500/100000 | Average Score: -148.85 | Epsilon: 0.0100
# Episode 59600/100000 | Average Score: -150.95 | Epsilon: 0.0100
# Episode 59700/100000 | Average Score: -149.85 | Epsilon: 0.0100
# Episode 59800/100000 | Average Score: -154.55 | Epsilon: 0.0100
# Episode 59900/100000 | Average Score: -148.00 | Epsilon: 0.0100
# Episode 60000/100000 | Average Score: -149.70 | Epsilon: 0.0100
# Episode 60100/100000 | Average Score: -149.70 | Epsilon: 0.0100
# Episode 60200/100000 | Average Score: -148.50 | Epsilon: 0.0100
# Episode 60300/100000 | Average Score: -146.40 | Epsilon: 0.0100
# Episode 60400/100000 | Average Score: -150.85 | Epsilon: 0.0100
# Episode 60500/100000 | Average Score: -147.55 | Epsilon: 0.0100
# Episode 60600/100000 | Average Score: -147.15 | Epsilon: 0.0100
# Episode 60700/100000 | Average Score: -148.25 | Epsilon: 0.0100
# Episode 60800/100000 | Average Score: -147.90 | Epsilon: 0.0100
# Episode 60900/100000 | Average Score: -149.95 | Epsilon: 0.0100
# Episode 61000/100000 | Average Score: -148.60 | Epsilon: 0.0100
# Episode 61100/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 61200/100000 | Average Score: -149.65 | Epsilon: 0.0100
# Episode 61300/100000 | Average Score: -148.55 | Epsilon: 0.0100
# Episode 61400/100000 | Average Score: -150.70 | Epsilon: 0.0100
# Episode 61500/100000 | Average Score: -149.20 | Epsilon: 0.0100
# Episode 61600/100000 | Average Score: -146.95 | Epsilon: 0.0100
# Episode 61700/100000 | Average Score: -145.55 | Epsilon: 0.0100
# Episode 61800/100000 | Average Score: -149.15 | Epsilon: 0.0100
# Episode 61900/100000 | Average Score: -146.25 | Epsilon: 0.0100
# Episode 62000/100000 | Average Score: -150.30 | Epsilon: 0.0100
# Episode 62100/100000 | Average Score: -151.20 | Epsilon: 0.0100
# Episode 62200/100000 | Average Score: -146.50 | Epsilon: 0.0100
# Episode 62300/100000 | Average Score: -150.25 | Epsilon: 0.0100
# Episode 62400/100000 | Average Score: -144.05 | Epsilon: 0.0100
# Episode 62500/100000 | Average Score: -149.70 | Epsilon: 0.0100
# Episode 62600/100000 | Average Score: -148.95 | Epsilon: 0.0100
# Episode 62700/100000 | Average Score: -145.65 | Epsilon: 0.0100
# Episode 62800/100000 | Average Score: -149.50 | Epsilon: 0.0100
# Episode 62900/100000 | Average Score: -147.50 | Epsilon: 0.0100
# Episode 63000/100000 | Average Score: -151.20 | Epsilon: 0.0100
# Episode 63100/100000 | Average Score: -150.60 | Epsilon: 0.0100
# Episode 63200/100000 | Average Score: -146.95 | Epsilon: 0.0100
# Episode 63300/100000 | Average Score: -150.20 | Epsilon: 0.0100
# Episode 63400/100000 | Average Score: -149.15 | Epsilon: 0.0100
# Episode 63500/100000 | Average Score: -150.10 | Epsilon: 0.0100
# Episode 63600/100000 | Average Score: -145.15 | Epsilon: 0.0100
# Episode 63700/100000 | Average Score: -148.80 | Epsilon: 0.0100
# Episode 63800/100000 | Average Score: -147.70 | Epsilon: 0.0100
# Episode 63900/100000 | Average Score: -147.50 | Epsilon: 0.0100
# Episode 64000/100000 | Average Score: -147.05 | Epsilon: 0.0100
# Episode 64100/100000 | Average Score: -147.80 | Epsilon: 0.0100
# Episode 64200/100000 | Average Score: -147.70 | Epsilon: 0.0100
# Episode 64300/100000 | Average Score: -147.65 | Epsilon: 0.0100
# Episode 64400/100000 | Average Score: -147.45 | Epsilon: 0.0100
# Episode 64500/100000 | Average Score: -147.80 | Epsilon: 0.0100
# Episode 64600/100000 | Average Score: -148.70 | Epsilon: 0.0100
# Episode 64700/100000 | Average Score: -148.10 | Epsilon: 0.0100
# Episode 64800/100000 | Average Score: -148.45 | Epsilon: 0.0100
# Episode 64900/100000 | Average Score: -145.40 | Epsilon: 0.0100
# Episode 65000/100000 | Average Score: -147.55 | Epsilon: 0.0100
# Episode 65100/100000 | Average Score: -151.85 | Epsilon: 0.0100
# Episode 65200/100000 | Average Score: -146.70 | Epsilon: 0.0100
# Episode 65300/100000 | Average Score: -147.85 | Epsilon: 0.0100
# Episode 65400/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 65500/100000 | Average Score: -147.20 | Epsilon: 0.0100
# Episode 65600/100000 | Average Score: -145.85 | Epsilon: 0.0100
# Episode 65700/100000 | Average Score: -148.10 | Epsilon: 0.0100
# Episode 65800/100000 | Average Score: -146.35 | Epsilon: 0.0100
# Episode 65900/100000 | Average Score: -150.05 | Epsilon: 0.0100
# Episode 66000/100000 | Average Score: -148.40 | Epsilon: 0.0100
# Episode 66100/100000 | Average Score: -150.25 | Epsilon: 0.0100
# Episode 66200/100000 | Average Score: -149.60 | Epsilon: 0.0100
# Episode 66300/100000 | Average Score: -151.80 | Epsilon: 0.0100
# Episode 66400/100000 | Average Score: -149.70 | Epsilon: 0.0100
# Episode 66500/100000 | Average Score: -148.35 | Epsilon: 0.0100
# Episode 66600/100000 | Average Score: -144.55 | Epsilon: 0.0100
# Episode 66700/100000 | Average Score: -150.75 | Epsilon: 0.0100
# Episode 66800/100000 | Average Score: -146.10 | Epsilon: 0.0100
# Episode 66900/100000 | Average Score: -144.65 | Epsilon: 0.0100
# Episode 67000/100000 | Average Score: -148.25 | Epsilon: 0.0100
# Episode 67100/100000 | Average Score: -148.60 | Epsilon: 0.0100
# Episode 67200/100000 | Average Score: -151.80 | Epsilon: 0.0100
# Episode 67300/100000 | Average Score: -149.05 | Epsilon: 0.0100
# Episode 67400/100000 | Average Score: -152.35 | Epsilon: 0.0100
# Episode 67500/100000 | Average Score: -146.95 | Epsilon: 0.0100
# Episode 67600/100000 | Average Score: -145.10 | Epsilon: 0.0100
# Episode 67700/100000 | Average Score: -149.25 | Epsilon: 0.0100
# Episode 67800/100000 | Average Score: -151.45 | Epsilon: 0.0100
# Episode 67900/100000 | Average Score: -147.95 | Epsilon: 0.0100
# Episode 68000/100000 | Average Score: -153.15 | Epsilon: 0.0100
# Episode 68100/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 68200/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 68300/100000 | Average Score: -149.25 | Epsilon: 0.0100
# Episode 68400/100000 | Average Score: -147.20 | Epsilon: 0.0100
# Episode 68500/100000 | Average Score: -150.85 | Epsilon: 0.0100
# Episode 68600/100000 | Average Score: -147.95 | Epsilon: 0.0100
# Episode 68700/100000 | Average Score: -151.85 | Epsilon: 0.0100
# Episode 68800/100000 | Average Score: -147.75 | Epsilon: 0.0100
# Episode 68900/100000 | Average Score: -146.30 | Epsilon: 0.0100
# Episode 69000/100000 | Average Score: -149.75 | Epsilon: 0.0100
# Episode 69100/100000 | Average Score: -147.00 | Epsilon: 0.0100
# Episode 69200/100000 | Average Score: -147.15 | Epsilon: 0.0100
# Episode 69300/100000 | Average Score: -150.40 | Epsilon: 0.0100
# Episode 69400/100000 | Average Score: -149.20 | Epsilon: 0.0100
# Episode 69500/100000 | Average Score: -150.35 | Epsilon: 0.0100
# Episode 69600/100000 | Average Score: -146.85 | Epsilon: 0.0100
# Episode 69700/100000 | Average Score: -151.30 | Epsilon: 0.0100
# Episode 69800/100000 | Average Score: -145.55 | Epsilon: 0.0100
# Episode 69900/100000 | Average Score: -150.80 | Epsilon: 0.0100
# Episode 70000/100000 | Average Score: -148.00 | Epsilon: 0.0100
# Episode 70100/100000 | Average Score: -151.00 | Epsilon: 0.0100
# Episode 70200/100000 | Average Score: -147.50 | Epsilon: 0.0100
# Episode 70300/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 70400/100000 | Average Score: -152.40 | Epsilon: 0.0100
# Episode 70500/100000 | Average Score: -149.90 | Epsilon: 0.0100
# Episode 70600/100000 | Average Score: -150.65 | Epsilon: 0.0100
# Episode 70700/100000 | Average Score: -146.30 | Epsilon: 0.0100
# Episode 70800/100000 | Average Score: -149.25 | Epsilon: 0.0100
# Episode 70900/100000 | Average Score: -145.85 | Epsilon: 0.0100
# Episode 71000/100000 | Average Score: -149.15 | Epsilon: 0.0100
# Episode 71100/100000 | Average Score: -147.00 | Epsilon: 0.0100
# Episode 71200/100000 | Average Score: -146.45 | Epsilon: 0.0100
# Episode 71300/100000 | Average Score: -148.60 | Epsilon: 0.0100
# Episode 71400/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 71500/100000 | Average Score: -145.70 | Epsilon: 0.0100
# Episode 71600/100000 | Average Score: -150.80 | Epsilon: 0.0100
# Episode 71700/100000 | Average Score: -150.05 | Epsilon: 0.0100
# Episode 71800/100000 | Average Score: -150.90 | Epsilon: 0.0100
# Episode 71900/100000 | Average Score: -149.35 | Epsilon: 0.0100
# Episode 72000/100000 | Average Score: -146.60 | Epsilon: 0.0100
# Episode 72100/100000 | Average Score: -147.90 | Epsilon: 0.0100
# Episode 72200/100000 | Average Score: -150.65 | Epsilon: 0.0100
# Episode 72300/100000 | Average Score: -146.50 | Epsilon: 0.0100
# Episode 72400/100000 | Average Score: -145.60 | Epsilon: 0.0100
# Episode 72500/100000 | Average Score: -148.95 | Epsilon: 0.0100
# Episode 72600/100000 | Average Score: -148.75 | Epsilon: 0.0100
# Episode 72700/100000 | Average Score: -149.75 | Epsilon: 0.0100
# Episode 72800/100000 | Average Score: -149.40 | Epsilon: 0.0100
# Episode 72900/100000 | Average Score: -155.25 | Epsilon: 0.0100
# Episode 73000/100000 | Average Score: -150.75 | Epsilon: 0.0100
# Episode 73100/100000 | Average Score: -149.25 | Epsilon: 0.0100
# Episode 73200/100000 | Average Score: -147.75 | Epsilon: 0.0100
# Episode 73300/100000 | Average Score: -147.40 | Epsilon: 0.0100
# Episode 73400/100000 | Average Score: -149.30 | Epsilon: 0.0100
# Episode 73500/100000 | Average Score: -149.35 | Epsilon: 0.0100
# Episode 73600/100000 | Average Score: -149.30 | Epsilon: 0.0100
# Episode 73700/100000 | Average Score: -149.30 | Epsilon: 0.0100
# Episode 73800/100000 | Average Score: -149.20 | Epsilon: 0.0100
# Episode 73900/100000 | Average Score: -153.55 | Epsilon: 0.0100
# Episode 74000/100000 | Average Score: -148.65 | Epsilon: 0.0100
# Episode 74100/100000 | Average Score: -145.80 | Epsilon: 0.0100
# Episode 74200/100000 | Average Score: -149.80 | Epsilon: 0.0100
# Episode 74300/100000 | Average Score: -149.50 | Epsilon: 0.0100
# Episode 74400/100000 | Average Score: -148.40 | Epsilon: 0.0100
# Episode 74500/100000 | Average Score: -150.80 | Epsilon: 0.0100
# Episode 74600/100000 | Average Score: -146.30 | Epsilon: 0.0100
# Episode 74700/100000 | Average Score: -150.10 | Epsilon: 0.0100
# Episode 74800/100000 | Average Score: -149.75 | Epsilon: 0.0100
# Episode 74900/100000 | Average Score: -146.95 | Epsilon: 0.0100
# Episode 75000/100000 | Average Score: -148.35 | Epsilon: 0.0100
# Episode 75100/100000 | Average Score: -152.05 | Epsilon: 0.0100
# Episode 75200/100000 | Average Score: -146.25 | Epsilon: 0.0100
# Episode 75300/100000 | Average Score: -151.20 | Epsilon: 0.0100
# Episode 75400/100000 | Average Score: -150.55 | Epsilon: 0.0100
# Episode 75500/100000 | Average Score: -150.60 | Epsilon: 0.0100
# Episode 75600/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 75700/100000 | Average Score: -151.15 | Epsilon: 0.0100
# Episode 75800/100000 | Average Score: -149.50 | Epsilon: 0.0100
# Episode 75900/100000 | Average Score: -146.90 | Epsilon: 0.0100
# Episode 76000/100000 | Average Score: -149.15 | Epsilon: 0.0100
# Episode 76100/100000 | Average Score: -148.95 | Epsilon: 0.0100
# Episode 76200/100000 | Average Score: -148.55 | Epsilon: 0.0100
# Episode 76300/100000 | Average Score: -150.00 | Epsilon: 0.0100
# Episode 76400/100000 | Average Score: -148.30 | Epsilon: 0.0100
# Episode 76500/100000 | Average Score: -154.45 | Epsilon: 0.0100
# Episode 76600/100000 | Average Score: -150.95 | Epsilon: 0.0100
# Episode 76700/100000 | Average Score: -150.35 | Epsilon: 0.0100
# Episode 76800/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 76900/100000 | Average Score: -147.75 | Epsilon: 0.0100
# Episode 77000/100000 | Average Score: -152.60 | Epsilon: 0.0100
# Episode 77100/100000 | Average Score: -150.35 | Epsilon: 0.0100
# Episode 77200/100000 | Average Score: -151.60 | Epsilon: 0.0100
# Episode 77300/100000 | Average Score: -149.80 | Epsilon: 0.0100
# Episode 77400/100000 | Average Score: -148.60 | Epsilon: 0.0100
# Episode 77500/100000 | Average Score: -151.55 | Epsilon: 0.0100
# Episode 77600/100000 | Average Score: -149.10 | Epsilon: 0.0100
# Episode 77700/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 77800/100000 | Average Score: -148.40 | Epsilon: 0.0100
# Episode 77900/100000 | Average Score: -148.60 | Epsilon: 0.0100
# Episode 78000/100000 | Average Score: -150.15 | Epsilon: 0.0100
# Episode 78100/100000 | Average Score: -149.55 | Epsilon: 0.0100
# Episode 78200/100000 | Average Score: -148.00 | Epsilon: 0.0100
# Episode 78300/100000 | Average Score: -153.00 | Epsilon: 0.0100
# Episode 78400/100000 | Average Score: -147.45 | Epsilon: 0.0100
# Episode 78500/100000 | Average Score: -150.55 | Epsilon: 0.0100
# Episode 78600/100000 | Average Score: -149.40 | Epsilon: 0.0100
# Episode 78700/100000 | Average Score: -151.05 | Epsilon: 0.0100
# Episode 78800/100000 | Average Score: -148.25 | Epsilon: 0.0100
# Episode 78900/100000 | Average Score: -147.40 | Epsilon: 0.0100
# Episode 79000/100000 | Average Score: -149.65 | Epsilon: 0.0100
# Episode 79100/100000 | Average Score: -152.45 | Epsilon: 0.0100
# Episode 79200/100000 | Average Score: -148.25 | Epsilon: 0.0100
# Episode 79300/100000 | Average Score: -151.95 | Epsilon: 0.0100
# Episode 79400/100000 | Average Score: -150.15 | Epsilon: 0.0100
# Episode 79500/100000 | Average Score: -147.55 | Epsilon: 0.0100
# Episode 79600/100000 | Average Score: -148.80 | Epsilon: 0.0100
# Episode 79700/100000 | Average Score: -148.25 | Epsilon: 0.0100
# Episode 79800/100000 | Average Score: -150.10 | Epsilon: 0.0100
# Episode 79900/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 80000/100000 | Average Score: -148.55 | Epsilon: 0.0100
# Episode 80100/100000 | Average Score: -148.30 | Epsilon: 0.0100
# Episode 80200/100000 | Average Score: -149.60 | Epsilon: 0.0100
# Episode 80300/100000 | Average Score: -145.50 | Epsilon: 0.0100
# Episode 80400/100000 | Average Score: -149.85 | Epsilon: 0.0100
# Episode 80500/100000 | Average Score: -149.10 | Epsilon: 0.0100
# Episode 80600/100000 | Average Score: -147.40 | Epsilon: 0.0100
# Episode 80700/100000 | Average Score: -147.20 | Epsilon: 0.0100
# Episode 80800/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 80900/100000 | Average Score: -148.80 | Epsilon: 0.0100
# Episode 81000/100000 | Average Score: -152.15 | Epsilon: 0.0100
# Episode 81100/100000 | Average Score: -147.75 | Epsilon: 0.0100
# Episode 81200/100000 | Average Score: -147.40 | Epsilon: 0.0100
# Episode 81300/100000 | Average Score: -147.55 | Epsilon: 0.0100
# Episode 81400/100000 | Average Score: -146.00 | Epsilon: 0.0100
# Episode 81500/100000 | Average Score: -147.55 | Epsilon: 0.0100
# Episode 81600/100000 | Average Score: -149.40 | Epsilon: 0.0100
# Episode 81700/100000 | Average Score: -150.40 | Epsilon: 0.0100
# Episode 81800/100000 | Average Score: -147.90 | Epsilon: 0.0100
# Episode 81900/100000 | Average Score: -145.05 | Epsilon: 0.0100
# Episode 82000/100000 | Average Score: -150.20 | Epsilon: 0.0100
# Episode 82100/100000 | Average Score: -150.40 | Epsilon: 0.0100
# Episode 82200/100000 | Average Score: -147.50 | Epsilon: 0.0100
# Episode 82300/100000 | Average Score: -153.10 | Epsilon: 0.0100
# Episode 82400/100000 | Average Score: -148.35 | Epsilon: 0.0100
# Episode 82500/100000 | Average Score: -148.45 | Epsilon: 0.0100
# Episode 82600/100000 | Average Score: -150.55 | Epsilon: 0.0100
# Episode 82700/100000 | Average Score: -149.35 | Epsilon: 0.0100
# Episode 82800/100000 | Average Score: -150.75 | Epsilon: 0.0100
# Episode 82900/100000 | Average Score: -150.55 | Epsilon: 0.0100
# Episode 83000/100000 | Average Score: -144.95 | Epsilon: 0.0100
# Episode 83100/100000 | Average Score: -152.25 | Epsilon: 0.0100
# Episode 83200/100000 | Average Score: -150.90 | Epsilon: 0.0100
# Episode 83300/100000 | Average Score: -151.15 | Epsilon: 0.0100
# Episode 83400/100000 | Average Score: -145.80 | Epsilon: 0.0100
# Episode 83500/100000 | Average Score: -150.05 | Epsilon: 0.0100
# Episode 83600/100000 | Average Score: -145.85 | Epsilon: 0.0100
# Episode 83700/100000 | Average Score: -148.75 | Epsilon: 0.0100
# Episode 83800/100000 | Average Score: -149.60 | Epsilon: 0.0100
# Episode 83900/100000 | Average Score: -150.15 | Epsilon: 0.0100
# Episode 84000/100000 | Average Score: -150.05 | Epsilon: 0.0100
# Episode 84100/100000 | Average Score: -148.05 | Epsilon: 0.0100
# Episode 84200/100000 | Average Score: -150.05 | Epsilon: 0.0100
# Episode 84300/100000 | Average Score: -152.20 | Epsilon: 0.0100
# Episode 84400/100000 | Average Score: -150.75 | Epsilon: 0.0100
# Episode 84500/100000 | Average Score: -153.90 | Epsilon: 0.0100
# Episode 84600/100000 | Average Score: -143.80 | Epsilon: 0.0100
# Episode 84700/100000 | Average Score: -149.45 | Epsilon: 0.0100
# Episode 84800/100000 | Average Score: -150.60 | Epsilon: 0.0100
# Episode 84900/100000 | Average Score: -151.25 | Epsilon: 0.0100
# Episode 85000/100000 | Average Score: -150.95 | Epsilon: 0.0100
# Episode 85100/100000 | Average Score: -147.45 | Epsilon: 0.0100
# Episode 85200/100000 | Average Score: -148.30 | Epsilon: 0.0100
# Episode 85300/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 85400/100000 | Average Score: -149.05 | Epsilon: 0.0100
# Episode 85500/100000 | Average Score: -145.85 | Epsilon: 0.0100
# Episode 85600/100000 | Average Score: -148.65 | Epsilon: 0.0100
# Episode 85700/100000 | Average Score: -142.90 | Epsilon: 0.0100
# Episode 85800/100000 | Average Score: -146.35 | Epsilon: 0.0100
# Episode 85900/100000 | Average Score: -147.35 | Epsilon: 0.0100
# Episode 86000/100000 | Average Score: -145.95 | Epsilon: 0.0100
# Episode 86100/100000 | Average Score: -149.30 | Epsilon: 0.0100
# Episode 86200/100000 | Average Score: -150.90 | Epsilon: 0.0100
# Episode 86300/100000 | Average Score: -152.25 | Epsilon: 0.0100
# Episode 86400/100000 | Average Score: -147.40 | Epsilon: 0.0100
# Episode 86500/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 86600/100000 | Average Score: -147.35 | Epsilon: 0.0100
# Episode 86700/100000 | Average Score: -149.70 | Epsilon: 0.0100
# Episode 86800/100000 | Average Score: -147.15 | Epsilon: 0.0100
# Episode 86900/100000 | Average Score: -155.75 | Epsilon: 0.0100
# Episode 87000/100000 | Average Score: -147.40 | Epsilon: 0.0100
# Episode 87100/100000 | Average Score: -150.55 | Epsilon: 0.0100
# Episode 87200/100000 | Average Score: -147.80 | Epsilon: 0.0100
# Episode 87300/100000 | Average Score: -148.15 | Epsilon: 0.0100
# Episode 87400/100000 | Average Score: -154.80 | Epsilon: 0.0100
# Episode 87500/100000 | Average Score: -150.25 | Epsilon: 0.0100
# Episode 87600/100000 | Average Score: -149.50 | Epsilon: 0.0100
# Episode 87700/100000 | Average Score: -152.40 | Epsilon: 0.0100
# Episode 87800/100000 | Average Score: -148.05 | Epsilon: 0.0100
# Episode 87900/100000 | Average Score: -151.60 | Epsilon: 0.0100
# Episode 88000/100000 | Average Score: -143.60 | Epsilon: 0.0100
# Episode 88100/100000 | Average Score: -150.70 | Epsilon: 0.0100
# Episode 88200/100000 | Average Score: -152.05 | Epsilon: 0.0100
# Episode 88300/100000 | Average Score: -150.30 | Epsilon: 0.0100
# Episode 88400/100000 | Average Score: -148.95 | Epsilon: 0.0100
# Episode 88500/100000 | Average Score: -150.00 | Epsilon: 0.0100
# Episode 88600/100000 | Average Score: -154.80 | Epsilon: 0.0100
# Episode 88700/100000 | Average Score: -148.85 | Epsilon: 0.0100
# Episode 88800/100000 | Average Score: -150.10 | Epsilon: 0.0100
# Episode 88900/100000 | Average Score: -150.70 | Epsilon: 0.0100
# Episode 89000/100000 | Average Score: -149.00 | Epsilon: 0.0100
# Episode 89100/100000 | Average Score: -146.75 | Epsilon: 0.0100
# Episode 89200/100000 | Average Score: -149.45 | Epsilon: 0.0100
# Episode 89300/100000 | Average Score: -151.95 | Epsilon: 0.0100
# Episode 89400/100000 | Average Score: -149.70 | Epsilon: 0.0100
# Episode 89500/100000 | Average Score: -145.30 | Epsilon: 0.0100
# Episode 89600/100000 | Average Score: -150.95 | Epsilon: 0.0100
# Episode 89700/100000 | Average Score: -146.40 | Epsilon: 0.0100
# Episode 89800/100000 | Average Score: -150.30 | Epsilon: 0.0100
# Episode 89900/100000 | Average Score: -146.95 | Epsilon: 0.0100
# Episode 90000/100000 | Average Score: -147.20 | Epsilon: 0.0100
# Episode 90100/100000 | Average Score: -150.30 | Epsilon: 0.0100
# Episode 90200/100000 | Average Score: -151.15 | Epsilon: 0.0100
# Episode 90300/100000 | Average Score: -147.00 | Epsilon: 0.0100
# Episode 90400/100000 | Average Score: -150.70 | Epsilon: 0.0100
# Episode 90500/100000 | Average Score: -147.05 | Epsilon: 0.0100
# Episode 90600/100000 | Average Score: -148.05 | Epsilon: 0.0100
# Episode 90700/100000 | Average Score: -151.95 | Epsilon: 0.0100
# Episode 90800/100000 | Average Score: -152.45 | Epsilon: 0.0100
# Episode 90900/100000 | Average Score: -151.25 | Epsilon: 0.0100
# Episode 91000/100000 | Average Score: -147.40 | Epsilon: 0.0100
# Episode 91100/100000 | Average Score: -149.75 | Epsilon: 0.0100
# Episode 91200/100000 | Average Score: -147.10 | Epsilon: 0.0100
# Episode 91300/100000 | Average Score: -147.10 | Epsilon: 0.0100
# Episode 91400/100000 | Average Score: -150.00 | Epsilon: 0.0100
# Episode 91500/100000 | Average Score: -149.95 | Epsilon: 0.0100
# Episode 91600/100000 | Average Score: -148.90 | Epsilon: 0.0100
# Episode 91700/100000 | Average Score: -147.95 | Epsilon: 0.0100
# Episode 91800/100000 | Average Score: -151.05 | Epsilon: 0.0100
# Episode 91900/100000 | Average Score: -147.50 | Epsilon: 0.0100
# Episode 92000/100000 | Average Score: -145.85 | Epsilon: 0.0100
# Episode 92100/100000 | Average Score: -147.90 | Epsilon: 0.0100
# Episode 92200/100000 | Average Score: -147.85 | Epsilon: 0.0100
# Episode 92300/100000 | Average Score: -146.90 | Epsilon: 0.0100
# Episode 92400/100000 | Average Score: -144.90 | Epsilon: 0.0100
# Episode 92500/100000 | Average Score: -149.75 | Epsilon: 0.0100
# Episode 92600/100000 | Average Score: -151.45 | Epsilon: 0.0100
# Episode 92700/100000 | Average Score: -147.85 | Epsilon: 0.0100
# Episode 92800/100000 | Average Score: -152.25 | Epsilon: 0.0100
# Episode 92900/100000 | Average Score: -146.80 | Epsilon: 0.0100
# Episode 93000/100000 | Average Score: -144.65 | Epsilon: 0.0100
# Episode 93100/100000 | Average Score: -151.25 | Epsilon: 0.0100
# Episode 93200/100000 | Average Score: -150.15 | Epsilon: 0.0100
# Episode 93300/100000 | Average Score: -146.95 | Epsilon: 0.0100
# Episode 93400/100000 | Average Score: -146.65 | Epsilon: 0.0100
# Episode 93500/100000 | Average Score: -149.05 | Epsilon: 0.0100
# Episode 93600/100000 | Average Score: -149.35 | Epsilon: 0.0100
# Episode 93700/100000 | Average Score: -148.25 | Epsilon: 0.0100
# Episode 93800/100000 | Average Score: -144.75 | Epsilon: 0.0100
# Episode 93900/100000 | Average Score: -147.00 | Epsilon: 0.0100
# Episode 94000/100000 | Average Score: -145.95 | Epsilon: 0.0100
# Episode 94100/100000 | Average Score: -147.55 | Epsilon: 0.0100
# Episode 94200/100000 | Average Score: -148.10 | Epsilon: 0.0100
# Episode 94300/100000 | Average Score: -149.65 | Epsilon: 0.0100
# Episode 94400/100000 | Average Score: -148.20 | Epsilon: 0.0100
# Episode 94500/100000 | Average Score: -149.10 | Epsilon: 0.0100
# Episode 94600/100000 | Average Score: -152.80 | Epsilon: 0.0100
# Episode 94700/100000 | Average Score: -150.85 | Epsilon: 0.0100
# Episode 94800/100000 | Average Score: -150.45 | Epsilon: 0.0100
# Episode 94900/100000 | Average Score: -151.95 | Epsilon: 0.0100
# Episode 95000/100000 | Average Score: -148.65 | Epsilon: 0.0100
# Episode 95100/100000 | Average Score: -149.75 | Epsilon: 0.0100
# Episode 95200/100000 | Average Score: -151.00 | Epsilon: 0.0100
# Episode 95300/100000 | Average Score: -148.60 | Epsilon: 0.0100
# Episode 95400/100000 | Average Score: -148.05 | Epsilon: 0.0100
# Episode 95500/100000 | Average Score: -147.90 | Epsilon: 0.0100
# Episode 95600/100000 | Average Score: -150.35 | Epsilon: 0.0100
# Episode 95700/100000 | Average Score: -150.75 | Epsilon: 0.0100
# Episode 95800/100000 | Average Score: -147.40 | Epsilon: 0.0100
# Episode 95900/100000 | Average Score: -148.50 | Epsilon: 0.0100
# Episode 96000/100000 | Average Score: -148.55 | Epsilon: 0.0100
# Episode 96100/100000 | Average Score: -150.20 | Epsilon: 0.0100
# Episode 96200/100000 | Average Score: -149.65 | Epsilon: 0.0100
# Episode 96300/100000 | Average Score: -146.80 | Epsilon: 0.0100
# Episode 96400/100000 | Average Score: -152.60 | Epsilon: 0.0100
# Episode 96500/100000 | Average Score: -147.10 | Epsilon: 0.0100
# Episode 96600/100000 | Average Score: -145.30 | Epsilon: 0.0100
# Episode 96700/100000 | Average Score: -146.15 | Epsilon: 0.0100
# Episode 96800/100000 | Average Score: -146.45 | Epsilon: 0.0100
# Episode 96900/100000 | Average Score: -149.35 | Epsilon: 0.0100
# Episode 97000/100000 | Average Score: -151.25 | Epsilon: 0.0100
# Episode 97100/100000 | Average Score: -147.85 | Epsilon: 0.0100
# Episode 97200/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 97300/100000 | Average Score: -149.30 | Epsilon: 0.0100
# Episode 97400/100000 | Average Score: -147.55 | Epsilon: 0.0100
# Episode 97500/100000 | Average Score: -152.35 | Epsilon: 0.0100
# Episode 97600/100000 | Average Score: -150.90 | Epsilon: 0.0100
# Episode 97700/100000 | Average Score: -146.40 | Epsilon: 0.0100
# Episode 97800/100000 | Average Score: -147.75 | Epsilon: 0.0100
# Episode 97900/100000 | Average Score: -147.80 | Epsilon: 0.0100
# Episode 98000/100000 | Average Score: -147.25 | Epsilon: 0.0100
# Episode 98100/100000 | Average Score: -150.50 | Epsilon: 0.0100
# Episode 98200/100000 | Average Score: -150.20 | Epsilon: 0.0100
# Episode 98300/100000 | Average Score: -144.35 | Epsilon: 0.0100
# Episode 98400/100000 | Average Score: -148.60 | Epsilon: 0.0100
# Episode 98500/100000 | Average Score: -147.05 | Epsilon: 0.0100
# Episode 98600/100000 | Average Score: -149.90 | Epsilon: 0.0100
# Episode 98700/100000 | Average Score: -149.90 | Epsilon: 0.0100
# Episode 98800/100000 | Average Score: -152.75 | Epsilon: 0.0100
# Episode 98900/100000 | Average Score: -147.90 | Epsilon: 0.0100
# Episode 99000/100000 | Average Score: -149.80 | Epsilon: 0.0100
# Episode 99100/100000 | Average Score: -150.35 | Epsilon: 0.0100
# Episode 99200/100000 | Average Score: -148.85 | Epsilon: 0.0100
